# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Automobile_data.csv')
df1 = pd.read_csv('Automobile_data.csv')

# %%
def DataIn(df):
    print(df.info())
    print("-"* 20)
    print(df.dtypes)
    print("-"* 20)
    d = df.isnull().sum()
    print(d[d>0])
DataIn(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.describe(include= 'all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               205     205       205        205
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                41      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           205        205          205             205  205.000000  ...
# ...

# %%
df = df.replace('?', np.nan)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df['price'].head(21)
# Out:
# 0     13495
# 1     16500
# 2     16500
# 3     13950
# 4     17450
# 5     15250
# 6     17710
# 7     18920
# 8     23875
# 9       NaN
# 10    16430
# 11    16925
# 12    20970
# 13    21105
# 14    24565
# 15    30760
# 16    41315
# 17    36880
# 18     5151
# 19     6295
# 20     6575
# Name: price, dtype: object

# %%
df.dropna(subset = ['price'], axis = 0, inplace = True)
df['price'].head(21)
# Out:
# 0     13495
# 1     16500
# 2     16500
# 3     13950
# 4     17450
# 5     15250
# 6     17710
# 7     18920
# 8     23875
# 10    16430
# 11    16925
# 12    20970
# 13    21105
# 14    24565
# 15    30760
# 16    41315
# 17    36880
# 18     5151
# 19     6295
# 20     6575
# 21     5572
# Name: price, dtype: object

# %%
DataIn(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
df['bore'] = df['bore'].astype(float)

# %%
mean_bore = df['bore'].mean()
df['bore'].loc[53:61]
# Out:
# 53    3.03
# 54    3.08
# 55     NaN
# 56     NaN
# 57     NaN
# 58     NaN
# 59    3.39
# 60    3.39
# 61    3.39
# Name: bore, dtype: float64

# %%
df['bore'] = df['bore'].replace(np.nan, mean_bore)
df['bore'].loc[53:61]
# Out:
# 53    3.030000
# 54    3.080000
# 55    3.330711
# 56    3.330711
# 57    3.330711
# 58    3.330711
# 59    3.390000
# 60    3.390000
# 61    3.390000
# Name: bore, dtype: float64

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df['stroke'] = df['stroke'].astype(float)
mean_stroke = df['stroke'].mean()
df['stroke'] = df['stroke'].replace(np.nan, mean_stroke)

# %%
ob2l = ['normalized-losses','horsepower', 'peak-rpm']
df[ob2l] = df[ob2l].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
def mean_swap(x):
    df[x] = df[x].replace(np.nan, df[x].mean())

mean_swap(ob2l)

df['price'] = df['price'].astype(float)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
## ALREADY EXECUTED ONCE

df['city-mpg'] = 235 / df['city-mpg']
df.rename(columns = {'city-mpg': 'city-L/100km'}, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %%
# df['num-of-doors'] = df['num-of-doors'].astype('category')

# %%
mode = df['num-of-doors'].mode()[0]
mode
# Out:
# 'four'

# %%
df['num-of-doors'] = df['num-of-doors'].replace(np.nan, mode)

# %%
df.describe(include= 'all')
# Out:
#          symboling  normalized-losses    make fuel-type aspiration  \
# count   201.000000          201.00000     201       201        201
# unique         NaN                NaN      22         2          2
# top            NaN                NaN  toyota       gas        std
# freq           NaN                NaN      32       181        165
# mean      0.840796          122.00000     NaN       NaN        NaN
# std       1.254802           31.99625     NaN       NaN        NaN
# min      -2.000000           65.00000     NaN       NaN        NaN
# 25%       0.000000          101.00000     NaN       NaN        NaN
# 50%       1.000000          122.00000     NaN       NaN        NaN
# 75%       2.000000          137.00000     NaN       NaN        NaN
# max       3.000000          256.00000     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           201        201          201             201  201.000000  ...
# ...

# %%
binwidth = int((max(df['price']) - min(df['price'])) / 3)
bins = range(int(min(df['price'])), int(max(df['price'])), binwidth)
bins
# Out:
# range(5118, 45400, 13427)

# %%
df['price-binned'] = pd.cut(df['price'], bins, labels = ["Low", "Medium", "High"])

# %%
df.loc[ 15:20, {'price', 'price-binned'}]
# Out:
#    price-binned    price
# 15       Medium  30760.0
# 16         High  41315.0
# 17         High  36880.0
# 18          Low   5151.0
# 19          Low   6295.0
# 20          Low   6575.0

# %%
df['price-binned'].dtypes
# Out:
# CategoricalDtype(categories=['Low', 'Medium', 'High'], ordered=True)

# %%
dummy_variable = pd.get_dummies(df['fuel-type'])
dummy_variable.rename(columns= {'fuel-type': 'gas', 'fuel-type': 'diesel'}, inplace = True)
df = pd.concat([df, dummy_variable], axis = 1)
df.drop('fuel-type', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3              122.0  alfa-romero        std          two
# 1          3              122.0  alfa-romero        std          two
# 2          1              122.0  alfa-romero        std          two
# 3          2              164.0         audi        std         four
# 4          2              164.0         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  stroke  \
# 0  convertible          rwd           front        88.6   168.8  ...    2.68
# 1  convertible          rwd           front        88.6   168.8  ...    2.68
# 2    hatchback          rwd           front        94.5   171.2  ...    3.47
# 3        sedan          fwd           front        99.8   176.6  ...    3.40
# 4        sedan          4wd           front        99.4   176.6  ...    3.40
#
#    compression-ratio  horsepower peak-rpm city-L/100km  highway-mpg    price  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Descriptive statistics

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015  174.200995   65.889055
# std      1.254802           31.99625    6.066366   12.322175    2.101471
# min     -2.000000           65.00000   86.600000  141.100000   60.300000
# 25%      0.000000          101.00000   94.500000  166.800000   64.100000
# 50%      1.000000          122.00000   97.000000  173.200000   65.500000
# 75%      2.000000          137.00000  102.400000  183.500000   66.600000
# max      3.000000          256.00000  120.900000  208.100000   72.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.330711    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.316048
# ...

# %%
drive_wheel_count = df['drive-wheels'].value_counts()
drive_wheel_count
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
""" BOX PLOT
    displays min, max, outliers,
    upper quartile (Q3/75th percentile), median (50th percentile), lower quartile (Q1/25th percentile)
    upper q - lower q = interquartile range (IQR)
    min = Q1 - 1.5 * IQR
    max = Q3 + 1.5 * IQR
    also see the distribution and skewness of data
"""

sns.boxplot(x='drive-wheels', y='price', data=df)  
plt.show()

# %%
""" SCATTER PLOT: dot for each observation
This plot shows the relationship between two variables:
The predictor variable (x axis): is the variable that you are using to predict an outcome. In this case, our predictor variable is the engine size.
The target variable (y axis): is the variable that you are trying to predict. In this case, our target variable is the price, since this would be the outcome.

"""
# import matplotlib.cm as cm
x = df['engine-size']
y = df['price']
plt.scatter(x, y, color = 'blue') #cmap = cm.viridis)
plt.title('Scatter of Engine Size VS Price')
plt.xlabel('Engine Size')
plt.ylabel('Price')
# plt.colorbar()
plt.show()

## as the engine size increases, price is increased.
## hence positive linear relationship

# %%
## GROUPBY
## here we want to know which type of wheel is most valuable, 
# so we group “drive-wheels” and then average them. 
# we can select the columns ‘drive-wheels’,’body-style’ and ‘price’ , 
# then assign it to the variable “df_group”.


df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
gp = df[['drive-wheels', 'body-style', 'price']]
drive_wheels_avg = gp.groupby(['drive-wheels'], as_index = False).mean()
drive_wheels_avg
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
gp_avg = gp.groupby(['drive-wheels', 'body-style'], as_index = False).mean()
gp_avg
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
"""pivot() function is used to reshaped 
a given DataFrame organized by given index / column values. 
This function does not support data aggregation, multiple values 
will result in a MultiIndex in the columns."""

pivot_table = gp_avg.pivot(index = 'drive-wheels', columns = 'body-style')
pivot_table
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
pivot_table = pivot_table.fillna(0)
pivot_table
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
## HEATMAP
"""
Another way to represent the pivot table is using a heatmap plot. 
Heat map takes a rectangular grid of data and assigns a 
color intensity based on the data value at the grid points.
It is a great way to plot the target variable over multiple variables and 
through this get visual clues of the relationship between these variables 
and the target.
"""
sns.heatmap(pivot_table)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Analysis Of Variance (ANOVA)
#
# ### a statistical method used to test whether there are significant differences between the means of two or more groups.
# ####  ANOVA returns two parameters:
# ##### F-test score: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.
#
# ##### P-value: P-value tells how statistically significant is our calculated score value

# %%
group = df[['make', 'price']]
gp_anova = group.groupby(['make'], as_index = False)
from scipy import stats

# %%
anova_result = stats.f_oneway(gp_anova.get_group('honda')['price'], gp_anova.get_group('jaguar')['price'])
anova_result
# Out:
# F_onewayResult(statistic=400.925870564337, pvalue=1.0586193512077862e-11)

# %%
anova_result = stats.f_oneway(gp_anova.get_group('honda')['price'], gp_anova.get_group('subaru')['price'])
anova_result
# Out:
# F_onewayResult(statistic=0.19744030127462606, pvalue=0.6609478240622193)

# %% [markdown]
# # Correlation

# %%
sns.regplot(x = 'engine-size', y = 'price', data = df)
plt.ylim(0,)
plt.show()

# %% [markdown]
# # Pearson Correlation
#
# ### The Pearson Correlation measures the linear dependence between two variables X and Y. The resulting coefficient is a value between -1 and 1 inclusive, where:
# ### 1: total positive linear correlation,
# ### 0: no linear correlation, the two variables most likely do not affect each other
# ### -1: total negative linear correlation.

# %% [markdown]
# ### The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.
#
# ### p-value is < 0.001 we say there is strong evidence that the correlation is significant,
# ### the p-value is < 0.05; there is moderate evidence that the correlation is significant,
# ### the p-value is < 0.1; there is weak evidence that the correlation is significant, and
# ### the p-value is > 0.1; there is no evidence that the correlation is significant.T

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.139896          -0.029800    0.493203  0.608941
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075790           0.217300    0.371250  0.579731
# ...

# %%
pearson_coef, pval = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is ", pearson_coef," with a p-value of ", pval)
# Out:
# The Pearson Correlation Coefficient is  0.584641822265508  with a p-value of  8.076488270733218e-20

# %%
pearson_coef, pval = stats.pearsonr(df['width'], df['price'])
print("The Pearson Correlation Coefficient is ", pearson_coef," with a p-value of ", pval)
# Out:
# The Pearson Correlation Coefficient is  0.7512653440522676  with a p-value of  9.2003355104806e-38

# %%
c = df.corr()

fig, ax = plt.subplots(figsize = (12,10))
#generate cmap, red and blue
# colormap = sns.diverging_palette(200, 10, as_cmap = True)

sns.heatmap(c, cmap = 'viridis', annot = True, fmt = '.2f')
plt.xticks(range(len(c.columns)), c.columns)
plt.yticks(range(len(c.columns)), c.columns)
plt.show()
